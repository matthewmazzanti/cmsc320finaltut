# %%
import pandas as pd
import codecs

with codecs.open('billboard.csv', "r",encoding='utf-8', errors='ignore') as fdata:
    df = pd.read_csv(fdata)

df = df.loc[:, ~df.columns.str.contains('^Unnamed:')]
df
# Out:
#       position  year                                         title.href  \
# 0            1  1970  https://en.wikipedia.org/wiki/Bridge_over_Trou...
# 1            2  1970  https://en.wikipedia.org/wiki/(They_Long_to_Be...
# 2            3  1970  https://en.wikipedia.org/wiki/American_Woman_(...
# 3            4  1970  https://en.wikipedia.org/wiki/Raindrops_Keep_F...
# 4            5  1970  https://en.wikipedia.org/wiki/War_(Edwin_Starr...
# 5            6  1970  https://en.wikipedia.org/wiki/Ain%27t_No_Mount...
# 6            7  1970  https://en.wikipedia.org/wiki/I%27ll_Be_There_...
# 7            8  1970  https://en.wikipedia.org/wiki/Get_Ready_(The_T...
# 8            9  1970     https://en.wikipedia.org/wiki/Let_It_Be_(song)
# 9           10  1970  https://en.wikipedia.org/wiki/Band_of_Gold_(Fr...
# 10          11  1970  https://en.wikipedia.org/wiki/Mama_Told_Me_Not...
# 11          12  1970  https://en.wikipedia.org/wiki/Everything_Is_Be...
# ...

# %%
from pronounce3 import lyrics_analysis
# Out:
# 112
# 8
# 3.142857142857143
# 316
# 21
# 5
# 2.7142857142857144
# 221
# 26
# 8
# 3.1923076923076925
# 129

# %%
df[['mean','denom']]K = df['lyrics'].apply(lyrics_analysis)
df
# Out:
# 15
# 4
# 2.466666666666667
# 76
# 5
# 3
# 2.4
# 78
# 19
# 4
# 2.210526315789474
# 80
# 33
# 3
# 2.393939393939394
# 135
# 19
# 4
# 2.263157894736842
# 96
# 22
# 3
# 1.9545454545454546
# 74
# 7
# 3
# 2.0
# 80
# 26
# 3
# 1.9615384615384615
# 96
# 26
# 4
# 2.269230769230769
# 119
# 13
# 3
# 2.076923076923077
# 80
# 7
# 4
# 2.4285714285714284
# 56
# 7
# 7
# 3.4285714285714284
# 96
# 57
# 7
# 2.807017543859649
# 134
# 4
# 7
# 3.75
# 48
# 0
# 0
# -1
# 66
# 5
# 3
# 2.4
# 77
# 6
# 5
# 2.5
# 83
# 14
# 5
# 2.2857142857142856
# 78
# 4
# 4
# 3.25
# 45
# 12
# 7
# 2.3333333333333335
# 84
# 8
# 3
# 1.875
# 49
# 15
# 4
# 2.4
# 83
# 63
# 7
# 2.8253968253968256
# 187
# 13
# 4
# 2.4615384615384617
# 67
# 26
# 8
# 2.423076923076923
# 106
# 16
# 4
# 2.3125
# 70
# 29
# 3
# 2.103448275862069
# 103
# 41
# 4
# 2.4146341463414633
# 125
# 16
# 4
# 2.375
# 103
# 9
# 4
# 2.0
# 45
# 6
# 4
# 2.6666666666666665
# 64
# 5
# 4
# 2.4
# 51
# 0
# 0
# -1
# 49
# 5
# 2
# 2.0
# 47
# 12
# 3
# 2.1666666666666665
# 79
# 23
# 6
# ...
