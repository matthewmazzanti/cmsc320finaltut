# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

years = []
for year in range(1960, 2013):
    print(year,end=' ')
    soup = BeautifulSoup(requests.get("http://billboardtop100of.com/" + str(year) + "-2/").text, 'html.parser')
    yr = pd.read_html(str(soup.find_all('div',id='content')[0].find('table')))[0]
    yr['year'] = 1960
    years.append(yr)


print(2013,end=' ')
soup = BeautifulSoup(requests.get("http://billboardtop100of.com/2013-2/").text,'html.parser')
yr = []
for line in soup.find_all('div',id='content')[0].find('small').stripped_strings:
    line = line.replace(u'\xa0', u' ')
    yr.append(re.split(r'\.    | – ',line))

yr = pd.DataFrame(yr)
yr['year'] = 2013
years.append(yr)

print(2014,end=' ')
soup = BeautifulSoup(requests.get("http://billboardtop100of.com/2014-2/").text,'html.parser')
yr = pd.read_html(str(soup.find_all('div',class_='entry-content')[0].find('table')))[0]
yr['year'] = 2014
years.append(yr)

print(2015,end=' ')
soup = BeautifulSoup(requests.get("http://billboardtop100of.com/2015-2/").text,'html.parser')
soup = soup.find_all('div',class_='entry-content')[0].find('table')
for s in soup('p'):
    s.extract() 
yr = pd.read_html(str(soup))[0]
yr['year'] = 2015
years.append(yr)

artists = years[0].append(years[1:])
# Out:
# 1960 1961 1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015

# %%
artists = artists.reset_index(drop=True)
artists.columns = ['rank','artist','song','year']
artists
# Out:
#      rank                                             artist  \
# 0       1                                        Percy Faith
# 1       2                                         Jim Reeves
# 2       3                                    Everly Brothers
# 3       4                                     Johnny Preston
# 4       5                                       Mark Dinning
# 5       6                                         Brenda Lee
# 6       7                                      Elvis Presley
# 7       8                                        Jimmy Jones
# 8       9                                      Elvis Presley
# 9      10                                     Chubby Checker
# 10     11                                     Connie Francis
# 11     12                                       Bobby Rydell
# 12     13                                      Brothers Four
# 13     14                                         Jack Scott
# 14     15                                      Marty Robbins
# 15     16                                  Hollywood Argyles
# 16     17                                     Connie Francis
# 17     18                                         Brenda Lee
# 18     19                                       Brian Hyland
# 19     20                                        Roy Orbison
# 20     21                              Dion and The Belmonts
# 21     22                                     Connie Stevens
# 22     23                                          Paul Anka
# 23     24                                     Frankie Avalon
# 24     25                                           Ventures
# 25     26                                           Drifters
# 26     27                  Brook Benton and Dinah Washington
# 27     28                                      Johnny Horton
# 28     29                                          Sam Cooke
# 29     30                                    Everly Brothers
# ...   ...                                                ...
# 5570   71                                          Vance Joy
# 5571   72                     Jidenna feat. Roman GianArthur
# 5572   73                                          Elle King
# 5573   74                                     Meghan Trainor
# 5574   75                  Charlie Puth feat. Meghan Trainor
# 5575   76                   Meghan Trainor feat. John Legend
# 5576   77                                            Tove Lo
# 5577   78        James Newton Howard feat. Jennifer Lawrence
# 5578   79                                       O.T. Genasis
# 5579   80            Jessie J, Ariana Grande and Nicki Minaj
# 5580   81                                          Sam Smith
# 5581   82                          iLoveMakonnen feat. Drake
# 5582   83                                       iLoveMemphis
